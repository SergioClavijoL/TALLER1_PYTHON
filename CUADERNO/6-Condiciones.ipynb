# %% [markdown]
# # TALLER PYTHON
# ## Introducción a Python - Cuadernillos de estudio
#
# ## PONTIFICIA UNIVERSIDAD JAVERIANA
# ### Procesamiento de Alto Volumen de Datos
#
# **Fecha:** 9 De Agosto de 2026
#
# **Autor:** Sergio Samuel Clavijo López
#
# **ID:** 00020536744
#
# **Tema:** CONDICIONES PYTHON
#
# **Objetivo:** Introducción al uso y funcionamiento de condiciones en  **Python**.
#
# **Descripción:**
#
# Este cuaderno esta centrado en desarrollar varios ejercicios sobre el uso de condiciones en Python, para aprender el uso de las funciones de condiciones.

# %% [markdown]
# ## EJERCICIOS

# %% [markdown]
# Escribe una declaración if que determine si un disco musical tiene una calificación mayor a 8. Compruébalo utilizando el calificación del disco <b>“Back in Black”</b> el cual tiene un valor de 8.5. Si la condición es verdadera, imprime “"This album is Amazing!"”

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
rating = 8.5
if rating > 8:
    print ("This album is Amazing!")
#El rating nos da mayor que el valor de la condicion entonces se cumple
# Out:
# This album is Amazing!

# %% [markdown]
# Escribe una declaración if-else que determine lo siguiente. Si la calificación es mayor que 8 imprime “this album is amazing”. Si es menor o igual a 8 que imprima “this album is ok”.

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
rating = 8.5
if rating > 8:
    print ("this album is amazing")
else:
    print ("this album is ok")
# Out:
# this album is amazing

# %% [markdown]
# Escribe una declaración if que determine si un disco fue lanzado antes de 1980 o en los años 1991 o 1993. Si la condición es verdadera imprime el año de lanzamiento.

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
album_year = 1979

if album_year < 1980 or album_year == 1991 or album_year == 1993:
    print("El año de lanzamiento es", album_year)
    #En caso de cumplir las condiciones dice la fecha de lanzamiento, sino no escribe nada
# Out:
# El año de lanzamiento es 1979

# %% [markdown]
# ## Conclusiones
#
# Este cuaderno permitió comprender el uso de las condicionales en Python, resultando especialmente relevante al evidenciar diferencias de sintaxis frente a otros lenguajes previamente conocidos.
#
# Se abordaron de manera satisfactoria los operadores y las sentencias condicionales, elementos fundamentales para la resolución de problemas lógicos y la toma de decisiones dentro de un programa.
