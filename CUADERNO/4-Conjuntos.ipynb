# %% [markdown]
# # TALLER PYTHON
# ## Introducción a Python - Cuadernillos de estudio
#
# ## PONTIFICIA UNIVERSIDAD JAVERIANA
# ### Procesamiento de Alto Volumen de Datos
#
# **Fecha:** 9 De Agosto de 2026
#
# **Autor:** Sergio Samuel Clavijo López
#
# **ID:** 00020536744
#
# **Tema:** CONJUNTOS PYTHON
#
# **Objetivo:** Introducción al uso y funcionamiento de conjuntos en  **Python**.
#
# **Descripción:**
#
# Este cuaderno esta centrado en desarrollar varios ejercicios sobre el uso de conjuntos en Python, para aprender el uso de las funciones de conjuntos.

# %% [markdown]
# ## EJERCICIOS

# %% [markdown]
# Transformar la lista <code>['rap','house','electronic music', 'rap']</code> en un conjunto:

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
conjunto = set(['rap','house','electronic music','rap'])
conjunto
#Se crea el conjunto con el set
# Out:
# {'electronic music', 'house', 'rap'}

# %% [markdown]
# Considera que la lista <code>A = [1, 2, 2, 1]</code> y el conjunto <code>B = set([1, 2, 2, 1])</code> suman <code>sum(A) = sum(B)</code>

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
A = [1, 2, 2, 1]
B = set([1, 2, 2, 1])
print("La suma de A es:", sum(A))
print("La suma de B es:", sum(B))
# En el B al ser un conjunto los valores repetidos no entran entonces solo toma 1 y 2
# Out:
# La suma de A es: 6
# La suma de B es: 3

# %% [markdown]
# Crea un nuevo conjunto <code>album_set3</code> que sea la unión de <code>album_set1</code> y <code>album_set2</code>:

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo

album_set1 = set(["Thriller", 'AC/DC', 'Back in Black'])
album_set2 = set([ "AC/DC", "Back in Black", "The Dark Side of the Moon"])
album_set3 = album_set1.union(album_set2)
album_set3
#Con .union juntamos los 2 conjuntos
# Out:
# {'AC/DC', 'Back in Black', 'The Dark Side of the Moon', 'Thriller'}

# %% [markdown]
# Averigua si <code>album_set1</code> es un subconjunto de <code>album_set3</code>:

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
album_set1.issubset(album_set3)
#El issubset nos devuelve si es un subconjunto o no
# Out:
# True

# %% [markdown]
# ## Conclusiones
#
# Este cuaderno permitió comprender el funcionamiento y comportamiento de los conjuntos en Python, destacando que, al no almacenar valores duplicados, los resultados de una operación pueden variar frente a los obtenidos con una lista.
#
# Esto se evidenció en un ejercicio de suma, donde el resultado con la lista fue mayor que con el conjunto, ya que valores repetidos (como el 1 y el 2) solo se contaron una vez en este último.
#
# También resultó interesante aprender a identificar subconjuntos de manera sencilla sin recorrer elemento por elemento, lo que demuestra la eficiencia de esta estructura de datos.
