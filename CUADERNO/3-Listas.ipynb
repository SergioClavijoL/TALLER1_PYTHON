# %% [markdown]
# # TALLER PYTHON
# ## Introducción a Python - Cuadernillos de estudio
#
# ## PONTIFICIA UNIVERSIDAD JAVERIANA
# ### Procesamiento de Alto Volumen de Datos
#
# **Fecha:** 9 De Agosto de 2026
#
# **Autor:** Sergio Samuel Clavijo López
#
# **ID:** 00020536744
#
# **Tema:** LISTAS PYTHON
#
# **Objetivo:** Introducción al uso y funcionamiento de listas en  **Python**.
#
# **Descripción:**
#
# Este cuaderno esta centrado en desarrollar varios ejercicios sobre el uso de listas en Python, para aprender el uso de las funciones de listas.

# %% [markdown]
# ## EJERCICIOS

# %% [markdown]
# Crea una lista <code>a_lit</code> con los siguientes elementos <code>1</code>, <code>hello</code>, <code>[1,2,3]</code> y <code>True</code>.

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
a_list = [1, "hello", [1,2,3] , "True"]
a_list
# Out:
# [1, 'hello', [1, 2, 3], 'True']

# %% [markdown]
# Encuentra el valor almacenado en el índice 1 de <code>a_list</code>.

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
a_list[1]
# Buscamos el indice adentro de []
# Out:
# 'hello'

# %% [markdown]
# Obtén el elemento almacenado en el índice 1, 2 y 3 de <code>a_list</code>.

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
a_list[1:4]
# Ponemos de donde a donde lo queremos
# Out:
# ['hello', [1, 2, 3], 'True']

# %% [markdown]
# Concatena las siguientes listas <code>A = [1, 'a']</code> y <code>B = [2, 1, 'd']</code>:

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
A = [1, 'a']
B = [2, 1, 'd']
A + B
# Se juntan las 2 listas con el +
# Out:
# [1, 'a', 2, 1, 'd']

# %% [markdown]
# ## Conclusiones
#
# Este cuaderno permitió comprender cómo crear listas con distintos tipos de datos incluso listas o tuplas anidadas, junto con sus métodos y operaciones básicas, entendiendo mejor la organización y distribución de los datos en esta estructura.
#
# Se identificó que las listas son similares a las tuplas, pero con una diferencia clave: son **mutables**, permitiendo modificar los datos a través de sus índices.
#
# Finalmente, este tema ayudó a diferenciar cuándo usar tuplas y cuándo usar listas, reforzando la importancia de elegir la estructura adecuada según el problema a resolver.
