# %% [markdown]
# # TALLER PYTHON
# ## Introducción a Python - Cuadernillos de estudio
#
# ## PONTIFICIA UNIVERSIDAD JAVERIANA
# ### Procesamiento de Alto Volumen de Datos
#
# **Fecha:** 9 De Agosto de 2026
#
# **Autor:** Sergio Samuel Clavijo López
#
# **ID:** 00020536744
#
# **Tema:** CLASES PYTHON
#
# **Objetivo:** Introducción al uso y funcionamiento de clases en  **Python**.
#
# **Descripción:**
#
# Este cuaderno esta centrado en desarrollar varios ejercicios sobre el uso de clases en Python, para aprender el uso de las clases.

# %% [markdown]
# ## EJERCICIOS

# %% [markdown]
# ##**Actividad a realizar:**
#
#
# La clase matplotlib.patches.Ellipse, permite dibujar elipses desde [matplotlib](https://matplotlib.org/stable/api/_as_gen/matplotlib.patches.Ellipse.html). La clase se importa de la siguiente manera:
#
# *from matplotlib.patchs import Ellipse*
#
# Se puede dibujar entonces cualquier elipse, dando los argumentos:
#
# plt.gca().add_patch(Ellipse(xy, width, height, facecolor = color, edgecolor = edgecolor))
#
# Se requiere crear una clase Elipse, la cual el constructor sea con valores iniciales cualesquiera. Adicionalmente, la clase debe tener los siguientes métodos:
#
# 1.- Cambiar el ancho
#
# 2.- Cambiar el alto
#
# 3.- Cambiar el color de relleno
#
# 4.- Cambiar el color de borde
#
# 5.- Dibujar

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse

# %%
class Elipse:
    def __init__(self, xy=(0, 0), width=1, height=1, facecolor='blue', edgecolor='black'):
        self.xy = xy
        self.width = width
        self.height = height
        self.facecolor = facecolor
        self.edgecolor = edgecolor

# %%
def cambiar_ancho(self, nuevo_ancho):
        self.width = nuevo_ancho

# %%
def cambiar_alto(self, nuevo_alto):
        self.height = nuevo_alto

# %%
def cambiar_color_relleno(self, nuevo_color):
        self.facecolor = nuevo_color

# %%
def cambiar_color_borde(self, nuevo_color):
        self.edgecolor = nuevo_color

# %%
def dibujar(self):
        elipse = Ellipse(self.xy, self.width, self.height,
                          facecolor=self.facecolor, edgecolor=self.edgecolor)
        ax = plt.gca()
        ax.add_patch(elipse)
        ax.set_xlim(self.xy[0] - self.width, self.xy[0] + self.width)
        ax.set_ylim(self.xy[1] - self.height, self.xy[1] + self.height)
        ax.set_aspect('equal')
        plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse


class Elipse:
    def __init__(self, xy=(0, 0), width=1, height=1, facecolor='blue', edgecolor='black'):
        self.xy = xy
        self.width = width
        self.height = height
        self.facecolor = facecolor
        self.edgecolor = edgecolor

    def cambiar_ancho(self, nuevo_ancho):
        self.width = nuevo_ancho

    def cambiar_alto(self, nuevo_alto):
        self.height = nuevo_alto

    def cambiar_color_relleno(self, nuevo_color):
        self.facecolor = nuevo_color

    def cambiar_color_borde(self, nuevo_color):
        self.edgecolor = nuevo_color

    def dibujar(self):
        elipse = Ellipse(self.xy, self.width, self.height,
                          facecolor=self.facecolor, edgecolor=self.edgecolor)
        ax = plt.gca()
        ax.add_patch(elipse)
        ax.set_xlim(self.xy[0] - self.width, self.xy[0] + self.width)
        ax.set_ylim(self.xy[1] - self.height, self.xy[1] + self.height)
        ax.set_aspect('equal')
        plt.show()

# %%
mi_elipse = Elipse(xy=(0, 0), width=4, height=2, facecolor='red', edgecolor='black')
mi_elipse.cambiar_ancho(7)
mi_elipse.cambiar_color_relleno('red')
mi_elipse.dibujar()

# %% [markdown]
# ## Conclusiones
#
# Este cuaderno permitió comprender cómo se crean y comportan las clases en Python. Aunque la sintaxis difiere de lenguajes como Java, se mantienen las mismas bases de la programación orientada a objetos, lo que facilita la adaptación al crear clases y métodos.
#
# Se comprendió además el uso de atributos, métodos y el constructor, así como la importancia del parámetro `self` para acceder a los elementos de una clase. En conclusión, este tema es fundamental para estructurar programas de forma más ordenada, modular y reutilizable.
