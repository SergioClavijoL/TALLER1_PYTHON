# %% [markdown]
# # TALLER PYTHON
# ## Introducción a Python - Cuadernillos de estudio
#
# ## PONTIFICIA UNIVERSIDAD JAVERIANA
# ### Procesamiento de Alto Volumen de Datos
#
# **Fecha:** 9 De Agosto de 2026
#
# **Autor:** Sergio Samuel Clavijo López
#
# **ID:** 00020536744
#
# **Tema:** DICCIONARIOS PYTHON
#
# **Objetivo:** Introducción al uso y funcionamiento de diccionarios en  **Python**.
#
# **Descripción:**
#
# Este cuaderno esta centrado en desarrollar varios ejercicios sobre el uso de diccionarios en Python, para aprender el uso de las funciones de diccionarios.

# %% [markdown]
# ## EJERCICIOS

# %% [markdown]
# <b>Necesitarás este diccionario para las siguientes dos preguntas:</b>

# %%
# Pregunta - Diccionario de ejemplo

soundtrack_dic = {"The Bodyguard":"1992", "Saturday Night Fever":"1977"}
soundtrack_dic
# Out:
# {'The Bodyguard': '1992', 'Saturday Night Fever': '1977'}

# %% [markdown]
# a) En el diccionario <code>soundtrack_dict</code>. ¿Cuáles son las llaves?

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
soundtrack_dic.keys()
# Con .keys nos dice los nombres de las llaves
# Out:
# dict_keys(['The Bodyguard', 'Saturday Night Fever'])

# %% [markdown]
# b) En el diccionario <code>soundtrack_dict</code>. ¿Cuáles son los valores?

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
soundtrack_dic.values()
# Con .values nos da el valor de cada llave
# Out:
# dict_values(['1992', '1977'])

# %% [markdown]
# <b>Necesitarás este diccionario para las siguientes preguntas:</b>

# %% [markdown]
# Los discos <b>Back in Black</b>, <b>The Bodyguard</b> y <b>Thriller</b> poseen el siguiente record de ventas en millones, 50, 50 y 65 respectivamente:

# %% [markdown]
# a) Crea un diccionario <code>album_sales_dict</code> donde las llaves sean el nombre del disco y los valores la cantidad de ventas en millones.

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
album_sales_dict = {"The Bodyguard":50, "Back in Black":50, "Thriller":65}
album_sales_dict
# Creamos las llaves con su valor
# Out:
# {'The Bodyguard': 50, 'Back in Black': 50, 'Thriller': 65}

# %% [markdown]
# b) Usa el diccionario para encontrar las ventas totales de <b>Thriller</b>:

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
album_sales_dict["Thriller"]
# Poniendo la llave nos da su valor
# Out:
# 65

# %% [markdown]
# c) Encuentra los nombres de los discos dentro del diccionario mediante el método <code>keys</code>:

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
album_sales_dict.keys()
# Con keys nos da el nombre de los discos
# Out:
# dict_keys(['The Bodyguard', 'Back in Black', 'Thriller'])

# %% [markdown]
# d) Encuentra los records de ventas dentro del diccionario mediante el método <code>values</code>:

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
album_sales_dict.values()
# Asi tenemos las ventas de todos los discos
# Out:
# dict_values([50, 50, 65])

# %% [markdown]
# ## Conclusiones
#
# Este cuaderno permitió aprender el uso de los diccionarios, una estructura que almacena información en pares clave-valor, útil para organizar datos de forma clara y ordenada.
#
# A través de ejemplos como el ejercicio de ventas de discos, se comprendió cómo esta estructura facilita el acceso rápido a la información, con posibles aplicaciones en otros ámbitos, como usar el nombre de un jugador como clave y su número de campeonatos como valor.
#
# En conclusión, los diccionarios resultan especialmente útiles para almacenar información compleja, manteniendo los datos relacionados entre sí de manera eficiente y fácil de interpretar.
