# %% [markdown]
# # TALLER PYTHON
# ## Introducción a Python - Cuadernillos de estudio
#
# ## PONTIFICIA UNIVERSIDAD JAVERIANA
# ### Procesamiento de Alto Volumen de Datos
#
# **Fecha:** 9 De Agosto de 2026
#
# **Autor:** Sergio Samuel Clavijo López
#
# **ID:** 00020536744
#
# **Tema:** FUNCIONES PYTHON
#
# **Objetivo:** Introducción al uso y funcionamiento de funciones en  **Python**.
#
# **Descripción:**
#
# Este cuaderno esta centrado en desarrollar varios ejercicios sobre el uso de funciones en Python, para aprender el uso de las funciones.

# %% [markdown]
# ## EJERCICIOS

# %% [markdown]
# Cree una función que divida la primera entrada por la segunda entrada:

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
def div(a,b):
  return(a/b)
  #ahi nos devolveria la division entre los dos

# %% [markdown]
# Utilice la función <code> con </code> para la siguiente pregunta.

# %%
# Usa la función con para la siguiente pregunta

def con(a, b):
    return(a + b)

# %% [markdown]
# ¿Se puede usar la función <code> con </code> que definimos antes para agregar números enteros o cadenas?

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
#si, un ejemplo de esto seria
con(3, 10)
# Out:
# 13

# %% [markdown]
# ¿Se puede usar la función <code> con </code> que definimos antes para concentrar una lista o tupla?

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo
#Si, por ejemplo:
con(['a', 2], ['b', 3])
# Out:
# ['a', 2, 'b', 3]

# %% [markdown]
# ## Conclusiones
#
# Este cuaderno destaca la importancia del uso de funciones, ya que facilitan la reutilización del código y permiten mantener una mejor organización en los programas.
#
# También se explicó la diferencia entre variables **locales y globales**, comprendiendo que las variables creadas dentro de una función no pueden accederse directamente desde fuera de ella, lo que contribuye a un mejor control y estructura del código.
